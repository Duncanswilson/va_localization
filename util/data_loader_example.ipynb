# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import reno_driving

# %%
driving = reno_driving.RenoDriving("/home/richard/data/vae_localization_data/gps_images/driving_01_13_17/", 
                                   "/home/richard/data/vae_localization_data/gps_coords/driving_01_13_17/")

# %%
x,y = driving.next_batch(128)

# %%
imshow(x[0])
print x[0].shape
# Out:
# (480, 640, 3)

# %%
print y[0]
# Out:
# [   39.527072   -119.8398938  1383.546    ]
